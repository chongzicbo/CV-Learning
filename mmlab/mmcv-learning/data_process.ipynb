# %%
import mmcv
print(mmcv.__version__)
# Out:
# 2.0.1

# %%
# !ls /home/bocheng/data/images/duplicated.png
# Out:
# /home/bocheng/data/images/duplicated.png

# %%
image_path="/home/bocheng/data/images/duplicated.png"
img=mmcv.imread(image_path)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
plt.show()

# %%
img=mmcv.imread(image_path,flag='grayscale')
plt.imshow(img)
plt.show()

# %%
img_=mmcv.imread(img)
mmcv.imwrite(img,'out.jpg')
# Out:
# True

# %%
with open(image_path,'rb') as f:
    data=f.read()
img=mmcv.imfrombytes(data)

# %%
mmcv.imshow(image_path)
